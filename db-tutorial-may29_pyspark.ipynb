# %%
create a Spark DataFrame with Boston Safety Data from Azure Open Datasets, and use SQL to query the data.

The following command sets the Azure storage access information.

# %%
blob_account_name = "azureopendatastorage"
blob_container_name = "citydatacontainer"
blob_relative_path = "Safety/Release/city=Boston"
blob_sas_token = r"?st=2019-02-26T02%3A34%3A32Z&se=2119-02-27T02%3A34%3A00Z&sp=rl&sv=2018-03-28&sr=c&sig=XlJVWA7fMXCSxCKqJm8psMOh0W4h7cSYO28coRqF2fs%3D"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
wasbs_path = 'wasbs://%s@%s.blob.core.windows.net/%s' % (blob_container_name, blob_account_name, blob_relative_path)
spark.conf.set('fs.azure.sas.%s.%s.blob.core.windows.net' % (blob_container_name, blob_account_name), blob_sas_token)
print('Remote blob path: ' + wasbs_path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Remote blob path: wasbs://citydatacontainer@azureopendatastorage.blob.core.windows.net/Safety/Release/city=Boston
# </div>

# %%
df = spark.read.parquet(wasbs_path)
print('Register the DataFrame as a SQL temporary view: source')
df.createOrReplaceTempView('source')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Register the DataFrame as a SQL temporary view: source
# </div>

# %%
print('Displaying top 10 rows: ')
display(spark.sql('SELECT * FROM source LIMIT 10'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dataType</th><th>dataSubtype</th><th>dateTime</th><th>category</th><th>subcategory</th><th>status</th><th>address</th><th>latitude</th><th>longitude</th><th>source</th><th>extendedProperties</th></tr></thead><tbody><tr><td>Safety</td><td>311_All</td><td>2012-07-19T14:10:16.000+0000</td><td>Housing</td><td>No Utilities Residential - Water</td><td>Closed</td><td>14 Ballou Ave  Dorchester  MA  02124</td><td>42.2872</td><td>-71.0804</td><td>Constituent Call</td><td></td></tr><tr><td>Safety</td><td>311_All</td><td>2019-07-23T10:32:00.000+0000</td><td>Sanitation</td><td>Schedule a Bulk Item Pickup</td><td>Closed</td><td>32 Brookledge St  Dorchester  MA  02121</td><td>42.3099</td><td>-71.09</td><td>Employee Generated</td><td></td></tr><tr><td>Safety</td><td>311_All</td><td>2018-01-06T12:36:00.000+0000</td><td>Administrative & General Requests</td><td>Misc. Snow Complaint</td><td>Open</td><td>409 Corey St  West Roxbury  MA  02132</td><td>42.298</td><td>-71.1684</td><td>Constituent Call</td><td></td></tr><tr><td>Safety</td><td>311_All</td><td>2019-02-07T10:30:17.000+0000</td><td>Highway Maintenance</td><td>Request for Pothole Repair</td><td>Closed</td><td>69 Mcgreevey Way  Mission Hill  MA  02120</td><td>42.3356</td><td>-71.0989</td><td>City Worker App</td><td></td></tr><tr><td>Safety</td><td>311_All</td><td>2012-11-15T15:05:03.000+0000</td><td>Sanitation</td><td>Schedule a Bulk Item Pickup</td><td>Closed</td><td>15 Park View St  Dorchester  MA  02121</td><td>42.3113</td><td>-71.0925</td><td>Constituent Call</td><td></td></tr><tr><td>Safety</td><td>311_All</td><td>2015-01-14T08:26:36.000+0000</td><td>Street Cleaning</td><td>Requests for Street Cleaning</td><td>Closed</td><td>83 Orleans St  East Boston  MA  02128</td><td>42.3689</td><td>-71.0372</td><td>City Worker App</td><td></td></tr><tr><td>Safety</td><td>311_All</td><td>2015-10-07T08:29:00.000+0000</td><td>Housing</td><td>Mice Infestation - Residential</td><td>Open</td><td>4 Mount Everett St  Dorchester  MA  02125</td><td>42.3594</td><td>-71.0587</td><td>Constituent Call</td><td></td></tr><tr><td>Safety</td><td>311_All</td><td>2020-05-20T19:26:40.000+0000</td><td>Street Cleaning</td><td>Requests for Street Cleaning</td><td>Closed</td><td>25 E Concord St  Roxbury  MA  02118</td><td>42.3373</td><td>-71.0745</td><td>Citizens Connect App</td><td></td></tr><tr><td>Safety</td><td>311_All</td><td>2013-07-14T10:05:43.000+0000</td><td>Sanitation</td><td>Schedule a Bulk Item Pickup SS</td><td>Closed</td><td>111 Woodley Ave  West Roxbury  MA  02132</td><td>42.2628</td><td>-71.1507</td><td>Self Service</td><td></td></tr><tr><td>Safety</td><td>311_All</td><td>2013-09-25T13:06:19.000+0000</td><td>Environmental Services</td><td>Rodent Activity</td><td>Closed</td><td>100-98 Hooker St  Allston  MA  02134</td><td>42.3593</td><td>-71.1264</td><td>Self Service</td><td></td></tr></tbody></table></div>
